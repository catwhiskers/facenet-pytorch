# %% [markdown]
# # Face tracking pipeline
#
# The following example illustrates how to use the `facenet_pytorch` python package to perform face detection and tracking on an image dataset using MTCNN.

# %%
# !pip install mmcv
# Out:
# Collecting mmcv
#   Downloading mmcv-1.3.4.tar.gz (295 kB)
#      |████████████████████████████████| 295 kB 7.5 MB/s eta 0:00:01
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from mmcv) (1.19.5)
# Requirement already satisfied: Pillow in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from mmcv) (8.1.0)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from mmcv) (5.4.1)
# Requirement already satisfied: yapf in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from mmcv) (0.30.0)
# Building wheels for collected packages: mmcv
#   Building wheel for mmcv (setup.py) ... done
#   Created wheel for mmcv: filename=mmcv-1.3.4-py2.py3-none-any.whl size=426558 sha256=8fe30e9c84a2bb6fd3b73365d51ed4e12808098f116a408765f9d9501505f85f
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/49/bf/80/8473be0c7b092e2b75588933f7c148c5417d495f2711e411df
# Successfully built mmcv
# Installing collected packages: addict, mmcv
# Successfully installed addict-2.4.0 mmcv-1.3.4

# %%
from facenet_pytorch import MTCNN
import torch
import numpy as np
import mmcv, cv2
from PIL import Image, ImageDraw
from IPython import display

# %% [markdown]
# #### Determine if an nvidia GPU is available

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Running on device: {}'.format(device))
# Out:
# Running on device: cuda:0

# %% [markdown]
# #### Define MTCNN module
#
# Note that, since MTCNN is a collection of neural nets and other code, the device must be passed in the following way to enable copying of objects when needed internally.
#
# See `help(MTCNN)` for more details.

# %%
mtcnn = MTCNN(keep_all=True, device=device)

# %% [markdown]
# #### Get a sample video
#
# We begin by loading a video with some faces in it. The `mmcv` PyPI package by mmlabs is used to read the video frames (it can be installed with `pip install mmcv`). Frames are then converted to PIL images.

# %%
video = mmcv.VideoReader('video.mp4')
frames = [Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)) for frame in video]

display.Video('video.mp4', width=640)
# Out:
# <video src="video.mp4" controls  width="640" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# #### Run video through MTCNN
#
# We iterate through each frame, detect faces, and draw their bounding boxes on the video frames.

# %%
frames_tracked = []
for i, frame in enumerate(frames):
    print('\rTracking frame: {}'.format(i + 1), end='')
    
    # Detect faces
    boxes, _ = mtcnn.detect(frame)
    
    # Draw faces
    frame_draw = frame.copy()
    draw = ImageDraw.Draw(frame_draw)
    for box in boxes:
        draw.rectangle(box.tolist(), outline=(255, 0, 0), width=6)
    
    # Add to frame list
    frames_tracked.append(frame_draw.resize((640, 360), Image.BILINEAR))
print('\nDone')
# Out:
# Tracking frame: 105
# Done

# %% [markdown]
# #### Display detections

# %%
d = display.display(frames_tracked[0], display_id=True)
i = 1
try:
    while True:
        d.update(frames_tracked[i % len(frames_tracked)])
        i += 1
except KeyboardInterrupt:
    pass
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0x7F286D21D5C0>

# %% [markdown]
# #### Save tracked video

# %%
dim = frames_tracked[0].size
fourcc = cv2.VideoWriter_fourcc(*'FMP4')    
video_tracked = cv2.VideoWriter('video_tracked.mp4', fourcc, 25.0, dim)
for frame in frames_tracked:
    video_tracked.write(cv2.cvtColor(np.array(frame), cv2.COLOR_RGB2BGR))
video_tracked.release()
